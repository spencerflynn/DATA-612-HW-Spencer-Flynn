# %% [markdown]
# <a href="https://colab.research.google.com/github/thoreau024/DATA-612-HW-Spencer-Flynn/blob/main/DATA_612_HW3_Spencer_Flynn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment for Week 3

# %% [markdown]
# ## Purpose:
# This assignment is intended to help you do the following:
# 1.	Become familiar with the Seaborn package
# 2.	Learn to visualize data using Seaborn
# 3.	Distinguish between various charts and when to utilize them

# %% [markdown]
# ## Action Items:
# •	Create three different charts using Seaborn package.
#   1. Create three different meaningful charts using Seaborn package on your selected data set.
#   2. Explain when it is best to use
#   3. Post your work in GitHub
#   4. Add a README file

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('https://raw.githubusercontent.com/franklin-univ-data-science/data/master/credit_default.csv')

# %% [markdown]
# Correlation Heatmap
#
# This type of plot alows the user to identify highly correlated variables and allows them to streamline the feature selection process.

# %%
cor = df.corr()
plt.figure(figsize=(18,18))
sns.heatmap(cor, cbar = True,  square = True, annot=True, fmt= '.2f',annot_kws={'size': 10},
            xticklabels=cor.columns.values,
            yticklabels=cor.columns.values)

# %% [markdown]
# Plot data and regression model fits across a FacetGrid.
#
# The FacetGrid class is useful when you want to visualize the distribution of a variable or the relationship between multiple variables separately within subsets of your dataset.

# %%
sns.lmplot(x='X1', y='Y', data=df)

# %% [markdown]
# Boxplot
#
# This type of graph is used to show the shape of the distribution, its central value, and its variability

# %%
sns.boxplot(data=df)
